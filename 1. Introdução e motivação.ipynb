# %% [markdown]
# #### Uso em Bancos :
# * Detecção de fraudes
# * Modelagem de risco de crédito
# * Mercado Futuro
#
# #### Tarefas :
# * Classificação
# * Regressão
# * Agrupamentp
# * Regras de associação
